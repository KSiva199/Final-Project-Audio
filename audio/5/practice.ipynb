# %%
import requests
from bs4 import BeautifulSoup
archive_url = "https://clarksonmsda.org/ml/audio2/data/numbers/5/"

def get_video_links():

	r = requests.get(archive_url)
	soup = BeautifulSoup(r.content,'html.parser')
	links = soup.findAll('a')
	video_links = [archive_url + link['href'] for link in links if link['href'].endswith('wav')]
	return video_links


def download_video_series(video_links):

	for link in video_links:
		file_name = link.split('/')[-1]

		print( "Downloading file:%s"%file_name)
		r = requests.get(link, stream = True)
		with open(file_name, 'wb') as f:
			for chunk in r.iter_content(chunk_size = 1024*1024):
				if chunk:
					f.write(chunk)
		
		print( "%s downloaded!\n"%file_name )

	print ("All videos downloaded!")
	return


video_links = get_video_links()

download_video_series(video_links)
# Out:
# Downloading file:american_f_Alexa_20230406110150.wav
# american_f_Alexa_20230406110150.wav downloaded!
#
# Downloading file:american_m_Josh_20230405130012.wav
# american_m_Josh_20230405130012.wav downloaded!
#
# Downloading file:american_m_Josh_20230405130013.wav
# american_m_Josh_20230405130013.wav downloaded!
#
# Downloading file:american_m_Selorm_20230408180030.wav
# american_m_Selorm_20230408180030.wav downloaded!
#
# Downloading file:american_m_Shaun_20230406131836.wav
# american_m_Shaun_20230406131836.wav downloaded!
#
# Downloading file:american_m_Shaun_20230406131837.wav
# american_m_Shaun_20230406131837.wav downloaded!
#
# Downloading file:americans_m_MaximusPowers_20230404125947.wav
# americans_m_MaximusPowers_20230404125947.wav downloaded!
#
# Downloading file:brazilian_m_Maeva_20230406094754.wav
# brazilian_m_Maeva_20230406094754.wav downloaded!
#
# Downloading file:indian_f_Bhavana_20230406090952.wav
# indian_f_Bhavana_20230406090952.wav downloaded!
#
# Downloading file:indian_f_Tejaswini_20230406085222.wav
# indian_f_Tejaswini_20230406085222.wav downloaded!
#
# Downloading file:indian_m_AntarikshLodhi_20230410114208.wav
# indian_m_AntarikshLodhi_20230410114208.wav downloaded!
#
# Downloading file:indian_m_AntarikshLodhi_20230410114212.wav
# indian_m_AntarikshLodhi_20230410114212.wav downloaded!
#
# Downloading file:indian_m_AntarikshLodhi_20230410114219.wav
# indian_m_AntarikshLodhi_20230410114219.wav downloaded!
#
# Downloading file:sri-lankan_f_Chethani_20230410101807.wav
# sri-lankan_f_Chethani_20230410101807.wav downloaded!
#
# Downloading file:sri-lankan_f_Dinushani_20230405112026.wav
# sri-lankan_f_Dinushani_20230405112026.wav downloaded!
#
# Downloading file:sri-lankan_f_Prathi_20230406133121.wav
# sri-lankan_f_Prathi_20230406133121.wav downloaded!
#
# Downloading file:sri-lankan_f_Thevasha_20230405112448.wav
# sri-lankan_f_Thevasha_20230405112448.wav downloaded!
#
# Downloading file:sri-lankan_m_Roshan_20230406205732.wav
# sri-lankan_m_Roshan_20230406205732.wav downloaded!
#
# Downloading file:sri-lankan_m_Roshan_20230406205733.wav
# sri-lankan_m_Roshan_20230406205733.wav downloaded!
#
# Downloading file:sri-lankan_m_Roshan_20230406205734.wav
# sri-lankan_m_Roshan_20230406205734.wav downloaded!
#
# Downloading file:venezuelan_f_Glories_20230406111759.wav
# venezuelan_f_Glories_20230406111759.wav downloaded!
#
# All videos downloaded!

# %%
import IPython.display as ipd
ipd.Audio('venezuelan_f_Glories_20230406111759.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os
path = "/Users/ksr/Machine Learning/Final Project Audio/audio/5"
dir_list = os.listdir(path)
for name in dir_list:
    print(name)
# Out:
# sri-lankan_f_Thevasha_20230405112448.wav
# indian_f_Tejaswini_20230406085222.wav
# american_m_Josh_20230405130012.wav
# american_m_Josh_20230405130013.wav
# american_f_Alexa_20230406110150.wav
# americans_m_MaximusPowers_20230404125947.wav
# sri-lankan_f_Prathi_20230406133121.wav
# indian_m_AntarikshLodhi_20230410114208.wav
# indian_f_Bhavana_20230406090952.wav
# indian_m_AntarikshLodhi_20230410114219.wav
# sri-lankan_f_Dinushani_20230405112026.wav
# american_m_Selorm_20230408180030.wav
# practice.ipynb
# sri-lankan_f_Chethani_20230410101807.wav
# indian_m_AntarikshLodhi_20230410114212.wav
# .ipynb_checkpoints
# sri-lankan_m_Roshan_20230406205734.wav
# venezuelan_f_Glories_20230406111759.wav
# brazilian_m_Maeva_20230406094754.wav
# american_m_Shaun_20230406131837.wav
# sri-lankan_m_Roshan_20230406205732.wav
# sri-lankan_m_Roshan_20230406205733.wav
# american_m_Shaun_20230406131836.wav

# %%
import librosa as librosa
import numpy as np
from matplotlib import pyplot as plt
import os
path = "/Users/ksr/Machine Learning/Final Project Audio/audio/5"
dir_list = os.listdir(path)
for name in range(0,len(dir_list)):
    y,sr=librosa.load(dir_list[name],sr=22050)
    librosa.display.waveshow(y,sr=sr,color='black')
# Out:
# /var/folders/z8/46_440p905v1pzk4x5tn867h0000gn/T/ipykernel_11587/2683974830.py:8: UserWarning: PySoundFile failed. Trying audioread instead.
#   y,sr=librosa.load(dir_list[name],sr=22050)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/core/audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/core/audio.py:209, in __soundfile_load(path, offset, duration, dtype)
#     207 else:
#     208     # Otherwise, create the soundfile object
# --> 209     context = sf.SoundFile(path)
#     211 with context as sf_desc:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soundfile.py:658, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     656 self._info = _create_info_struct(file, mode, samplerate, channels,
#     657                                  format, subtype, endian)
# --> 658 self._file = self._open(file, mode_int, closefd)
#     659 if set(mode).issuperset('r+') and self.seekable():
#     660     # Move write position to 0 (like in Python file objects)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soundfile.py:1216, in SoundFile._open(self, file, mode_int, closefd)
#    1215     err = _snd.sf_error(file_ptr)
# -> 1216     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1217 if mode_int == _snd.SFM_WRITE:
#    1218     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1219     # when opening a named pipe in SFM_WRITE mode.
#    1220     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening 'practice.ipynb': Format not recognised.
#
# During handling of the above exception, another exception occurred:
#
# NoBackendError                            Traceback (most recent call last)
# /Users/ksr/Machine Learning/Final Project Audio/audio/5/practice.ipynb Cell 4 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/ksr/Machine%20Learning/Final%20Project%20Audio/audio/5/practice.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> dir_list = os.listdir(path)
#       <a href='vscode-notebook-cell:/Users/ksr/Machine%20Learning/Final%20Project%20Audio/audio/5/practice.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> for name in range(0,len(dir_list)):
# ----> <a href='vscode-notebook-cell:/Users/ksr/Machine%20Learning/Final%20Project%20Audio/audio/5/practice.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     y,sr=librosa.load(dir_list[name],sr=22050)
#       <a href='vscode-notebook-cell:/Users/ksr/Machine%20Learning/Final%20Project%20Audio/audio/5/practice.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     librosa.display.waveshow(y,sr=sr,color='black')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/core/audio.py:184, in load(path, sr, mono, offset, duration, dtype, res_type)
#     180 if isinstance(path, (str, pathlib.PurePath)):
#     181     warnings.warn(
#     182         "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     183     )
# --> 184     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     185 else:
#     186     raise exc
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:60, in deprecated.<locals>.__wrapper(func, *args, **kwargs)
#      51 """Warn the user, and then proceed."""
#      52 warnings.warn(
#      53     "{:s}.{:s}\n\tDeprecated as of librosa version {:s}."
#      54     "\n\tIt will be removed in librosa version {:s}.".format(
#    (...)
#      58     stacklevel=3,  # Would be 2, but the decorator adds a level
#      59 )
# ---> 60 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/core/audio.py:241, in __audioread_load(path, offset, duration, dtype)
#     238     reader = path
#     239 else:
#     240     # If the input was not an audioread object, try to open it
# --> 241     reader = audioread.audio_open(path)
#     243 with reader as input_file:
#     244     sr_native = input_file.samplerate
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/audioread/__init__.py:132, in audio_open(path, backends)
#     129         pass
#     131 # All backends failed!
# --> 132 raise NoBackendError()
#
# NoBackendError:

# %%
dir_list[1]
# Out:
# 'indian_f_Tejaswini_20230406085222.wav'

# %%
D=librosa.stft(y)
s_db=librosa.amplitude_to_db(np.abs(D), ref=np.max)
s_db.shape
# Out:
# (1025, 41)

# %%
plt.figure(figsize=(14,5))
img=librosa.display.specshow(s_db,sr=sr,x_axis='s',y_axis='linear',hop_length=320)
plt.colorbar()

# %%
S=librosa.feature.melspectrogram(y=y,sr=sr,n_mels=128,)
s_db_mel=librosa.amplitude_to_db(S, ref=np.max)

# %%
plt.figure(figsize=(14,5))
img=librosa.display.specshow(s_db_mel,sr=sr,x_axis='s',y_axis='linear',hop_length=320)
plt.colorbar()

# %%
s_db_mel
# Out:
# array([[-80., -80., -80., ..., -80., -80., -80.],
#        [-80., -80., -80., ..., -80., -80., -80.],
#        [-80., -80., -80., ..., -80., -80., -80.],
#        ...,
#        [-80., -80., -80., ..., -80., -80., -80.],
#        [-80., -80., -80., ..., -80., -80., -80.],
#        [-80., -80., -80., ..., -80., -80., -80.]], dtype=float32)
